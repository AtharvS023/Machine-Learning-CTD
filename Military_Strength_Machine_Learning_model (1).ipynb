# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/global firepower 2022 wide.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    140 non-null    object
#  1   country_code               140 non-null    object
#  2   Active Personnel           140 non-null    int64
#  3   Aircraft Carriers          140 non-null    int64
#  4   Armored Vehicles           140 non-null    int64
#  5   Attack Helicopters         140 non-null    int64
#  6   Available Manpower         140 non-null    int64
#  7   Coastline Coverage         140 non-null    int64
#  8   Corvettes                  140 non-null    int64
#  9   Dedicated Attack           140 non-null    int64
#  10  Defense Budget             140 non-null    int64
#  11  Destroyers                 140 non-null    int64
#  12  External Debt              140 non-null    int64
#  13  Fighters/Interceptors      140 non-null    int64
#  14  Fit-for-Service            140 non-null    int64
#  15  Foreign Exchange/Gold      140 non-null    int64
#  16  Frigates                   140 non-null    int64
#  17  Helicopter Carriers        140 non-null    int64
#  18  Helicopters                140 non-null    int64
#  19  Labor Force                140 non-null    int64
#  20  Merchant Marine Fleet      140 non-null    int64
#  21  Mine Warfare               140 non-null    int64
#  22  Navy Ships                 140 non-null    int64
#  23  Oil Consumption            140 non-null    int64
#  24  Oil Production             140 non-null    int64
#  25  Oil Proven Reserves        140 non-null    int64
#  26  Paramilitary               140 non-null    int64
#  27  Patrol Vessels             140 non-null    int64
#  28  Ports / Trade Terminals    140 non-null    int64
#  29  Purchasing Power Parity    140 non-null    int64
#  30  Railway Coverage           140 non-null    int64
#  31  Reaching Mil Age Annually  140 non-null    int64
#  32  Reserve Personnel          140 non-null    int64
#  33  Roadway Coverage           140 non-null    int64
#  34  Rocket Projectors          140 non-null    int64
#  35  Self-Propelled Artillery   140 non-null    int64
#  36  Shared Borders             140 non-null    int64
#  37  Special-Mission            140 non-null    int64
#  38  Square Land Area           140 non-null    int64
#  39  Submarines                 140 non-null    int64
#  40  Tanker Fleet               140 non-null    int64
#  41  Tanks                      140 non-null    int64
#  42  Total Aircraft Strength    140 non-null    int64
#  43  Total Population           140 non-null    int64
#  44  Towed Artillery            140 non-null    int64
#  45  Trainers                   140 non-null    int64
#  46  Transports                 140 non-null    int64
#  47  Waterways (usable)         140 non-null    int64
# dtypes: int64(46), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# ##Data Preprocessing and Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# country                      0
# country_code                 0
# Active Personnel             0
# Aircraft Carriers            0
# Armored Vehicles             0
# Attack Helicopters           0
# Available Manpower           0
# Coastline Coverage           0
# Corvettes                    0
# Dedicated Attack             0
# Defense Budget               0
# Destroyers                   0
# External Debt                0
# Fighters/Interceptors        0
# Fit-for-Service              0
# Foreign Exchange/Gold        0
# Frigates                     0
# Helicopter Carriers          0
# Helicopters                  0
# Labor Force                  0
# Merchant Marine Fleet        0
# Mine Warfare                 0
# Navy Ships                   0
# Oil Consumption              0
# Oil Production               0
# Oil Proven Reserves          0
# Paramilitary                 0
# Patrol Vessels               0
# Ports / Trade Terminals      0
# Purchasing Power Parity      0
# Railway Coverage             0
# Reaching Mil Age Annually    0
# Reserve Personnel            0
# Roadway Coverage             0
# Rocket Projectors            0
# Self-Propelled Artillery     0
# Shared Borders               0
# Special-Mission              0
# Square Land Area             0
# Submarines                   0
# Tanker Fleet                 0
# Tanks                        0
# Total Aircraft Strength      0
# Total Population             0
# Towed Artillery              0
# Trainers                     0
# Transports                   0
# Waterways (usable)           0
# dtype: int64

# %%
#Taking first 15 and last 15 countries in list of countries (alphabetical)
first_df = df.iloc[:15,:]
second_df = df.iloc[-15:,:]

# %%
new_df = pd.concat([first_df, second_df]).reset_index()
new_df = new_df.drop(columns = ["country", "country_code"])
new_df
# Out:
#     index  Active Personnel  Aircraft Carriers  Armored Vehicles  \
# 0       0                 0                  0               530
# 1       1              8000                  0                76
# 2       2            130000                  0              6461
# 3       3            107000                  0              1210
# 4       4             83000                  0               800
# 5       5             45000                  0               673
# 6       6             59000                  0              1765
# 7       7             23000                  0               542
# 8       8             65000                  0              1762
# 9       9             10000                  0               833
# 10     10            165000                  0               837
# 11     11             45000                  0              1510
# 12     12             26000                  0               854
# 13     13              8000                  0                27
# 14     14             50000                  0               152
# 15    125             36000                  0               954
# 16    126            425000                  0             13270
# 17    127             30000                  0              2050
# 18    128             47000                  0              1056
# 19    129            200000                  0             12303
# 20    130             65000                  0              9255
# 21    131            194000                  2              5015
# 22    132           1390000                 11             45193
# 23    133             22000                  0               474
# 24    134             55000                  0              1215
# 25    135            137500                  0              2534
# 26    136            470000                  0              4420
# 27    137             45000                  0               300
# 28    138             16500                  0               226
# 29    139             30000                  0               318
#
#     Attack Helicopters  Available Manpower  Coastline Coverage  Corvettes  \
# 0                    0            14611901                   0          0
# 1                    0             1513309                 362          0
# 2                   45            20916812                 998          6
# 3                   15             6728529                1600          0
# 4                    0            20180574                4989          9
# 5                   20             1686501                   0          0
# 6                   22            10840189               25760          0
# 7                    0             3998189                   0          0
# 8                   17             5038319                 713          0
# 9                   22              824542                 161          2
# 10                   0            80408421                 580          6
# 11                  21             5004176                   0          0
# 12                   0             4829325                  67          0
# 13                   0              197207                   0          0
# 14                   0             5173902                   0          0
# 15                   0             5905668                1148          0
# 16                 107            42148498                7200         10
# 17                  10             2689506                1768          0
# 18                   5            15202129                   0          0
# 19                  34            22310276                2782          1
# 20                  30             5716835                1318          9
# 21                  24            30857260               12429          0
# 22                 910           147399295               19924         22
# 23                   0             1563190                 660          0
# 24                  33            16038254                 420          0
# 25                  10            14534577                2800          0
# 26                   0            53450591                3444         14
# 27                  14            11551712                1906          2
# 28                   0             6677236                   0          0
# 29                   6             5635395                   0          0
#
#     Dedicated Attack  Defense Budget  ...  Square Land Area  Submarines  \
# 0                  0        99050000  ...            652230           0
# 1                  0       192400000  ...             28748           0
# 2                 22      9700000000  ...           2381741           6
# 3                 18      1059270000  ...           1246700           0
# 4                  6      3064800000  ...           2780400           2
# 5                 10       632500000  ...             29743           0
# 6                 37     44618000000  ...           7741220           6
# 7                  0      3432000000  ...             83871           0
# 8                 11      1700000000  ...             86600           4
# 9                  0      1538800000  ...               760           0
# 10                 0      3890400000  ...            143998           2
# 11                67       723120000  ...            207600           0
# 12                 0      5513710000  ...             30528           0
# 13                 0        28908000  ...             38394           0
# 14                 0       476970000  ...           1098581           0
# 15                 0      1177200000  ...            163610           0
# 16                 0      9690000000  ...            783562          12
# 17                27       407070000  ...            488100           0
# 18                 0       934250000  ...            241038           0
# 19                29     11870000000  ...            603550           0
# 20                20     25266000000  ...             83600           0
# 21                23     68000000000  ...            243610          10
# 22               783    770000000000  ...           9826675          68
# 23                 7      1072600000  ...            176215           0
# 24                20       692520000  ...            447400           0
# 25                 0      1929600000  ...            912050           2
# 26                 0      6237600000  ...            331210           6
# 27                 0      1010070000  ...            527968           0
# 28                 0       251160000  ...            752618           0
# 29                 0       117390000  ...            390757           0
#
#     Tanker Fleet  Tanks  Total Aircraft Strength  Total Population  \
# 0              0      0                        0          37466414
# 1              0      0                       19           3088385
# 2              5   2196                      552          43576691
# 3              0    320                      299          33642646
# 4              2    349                      218          45864941
# 5              0    288                       64           3011609
# 6              6     59                      430          25809973
# 7              0     56                      102           8884864
# 8              0    510                      149          10282283
# 9              0    180                      110           1526929
# 10             0    320                      190         164098818
# 11             0    601                      201           9441842
# 12             0      0                      115          11778842
# 13             0      0                        2            857423
# 14             0     36                       63          11758869
# 15             0    145                      151          11811335
# 16             7   3022                     1057          82482383
# 17             0    680                       82           5579889
# 18             0    237                       49          44712143
# 19             0   2596                      318          43745640
# 20             3    354                      554           9856612
# 21             9    227                      693          67081000
# 22           627   6612                    13247         334998398
# 23             0     79                       50           3398239
# 24             0    420                      200          30842796
# 25             1    300                      256          29069153
# 26             0   2044                      218         102789598
# 27             0    200                      177          30399243
# 28             0     75                       97          19077816
# 29             0     50                       90          14829988
#
#     Towed Artillery  Trainers  Transports  Waterways (usable)
# 0                60         0           0                1200
# 1                 0         0           0                  41
# 2               450        87          58                   0
# 3               585        61          30                1300
# 4               172        70          22               11000
# 5               145        10           2                   0
# 6                54       113          38                2000
# 7                 0        13          11                   0
# 8               319        32           2                   0
# 9                26        37           3                   0
# 10              371        63          13                8370
# 11              228        30           4                2500
# 12                0        43           8                2043
# 13                0         0           0                   0
# 14               40        21          14               10000
# 15               86        29           9                   0
# 16             1189       270          81                1200
# 17              457         0           5                1300
# 18               35        12           2                   0
# 19             2040        71          32                2150
# 20               76       146          39                   0
# 21              126       247          40                3200
# 22             1339      2661         982               41009
# 23               64        17           8                1600
# 24               60         7          18                1100
# 25              104        80          50                7100
# 26              599        30           9               17702
# 27               43        30           8                   0
# 28               42        51          11                2250
# 29               60        38          14                   0
#
# [30 rows x 47 columns]

# %%
#Adding the indices data (which will become the dependent variable)
data = {"Power Index":[3.3736, 3.0023, 0.4724, 1.0931, 0.6091, 2.3169, 0.2377, 0.8924, 1.0251, 2.3269, 0.6851, 
0.8124, 1.1451, 35.8958, 1.5708, 1.3664, 0.1961, 1.6728, 2.2436, 0.3266, 0.5859, 0.1382, 0.0453, 
2.4526, 0.8272, 0.6664, 0.4521, 1.4754, 2.1966, 2.2498]}

# %%
indices = pd.DataFrame(data)

# %%
final_df = pd.concat([new_df, indices], axis = 1).drop(columns = ["index"])

# %%
final_df
# Out:
#     Active Personnel  Aircraft Carriers  Armored Vehicles  Attack Helicopters  \
# 0                  0                  0               530                   0
# 1               8000                  0                76                   0
# 2             130000                  0              6461                  45
# 3             107000                  0              1210                  15
# 4              83000                  0               800                   0
# 5              45000                  0               673                  20
# 6              59000                  0              1765                  22
# 7              23000                  0               542                   0
# 8              65000                  0              1762                  17
# 9              10000                  0               833                  22
# 10            165000                  0               837                   0
# 11             45000                  0              1510                  21
# 12             26000                  0               854                   0
# 13              8000                  0                27                   0
# 14             50000                  0               152                   0
# 15             36000                  0               954                   0
# 16            425000                  0             13270                 107
# 17             30000                  0              2050                  10
# 18             47000                  0              1056                   5
# 19            200000                  0             12303                  34
# 20             65000                  0              9255                  30
# 21            194000                  2              5015                  24
# 22           1390000                 11             45193                 910
# 23             22000                  0               474                   0
# 24             55000                  0              1215                  33
# 25            137500                  0              2534                  10
# 26            470000                  0              4420                   0
# 27             45000                  0               300                  14
# 28             16500                  0               226                   0
# 29             30000                  0               318                   6
#
#     Available Manpower  Coastline Coverage  Corvettes  Dedicated Attack  \
# 0             14611901                   0          0                 0
# 1              1513309                 362          0                 0
# 2             20916812                 998          6                22
# 3              6728529                1600          0                18
# 4             20180574                4989          9                 6
# 5              1686501                   0          0                10
# 6             10840189               25760          0                37
# 7              3998189                   0          0                 0
# 8              5038319                 713          0                11
# 9               824542                 161          2                 0
# 10            80408421                 580          6                 0
# 11             5004176                   0          0                67
# 12             4829325                  67          0                 0
# 13              197207                   0          0                 0
# 14             5173902                   0          0                 0
# 15             5905668                1148          0                 0
# 16            42148498                7200         10                 0
# 17             2689506                1768          0                27
# 18            15202129                   0          0                 0
# 19            22310276                2782          1                29
# 20             5716835                1318          9                20
# 21            30857260               12429          0                23
# 22           147399295               19924         22               783
# 23             1563190                 660          0                 7
# 24            16038254                 420          0                20
# 25            14534577                2800          0                 0
# 26            53450591                3444         14                 0
# 27            11551712                1906          2                 0
# 28             6677236                   0          0                 0
# 29             5635395                   0          0                 0
#
#     Defense Budget  Destroyers  ...  Submarines  Tanker Fleet  Tanks  \
# 0         99050000           0  ...           0             0      0
# 1        192400000           0  ...           0             0      0
# 2       9700000000           0  ...           6             5   2196
# 3       1059270000           0  ...           0             0    320
# 4       3064800000           4  ...           2             2    349
# 5        632500000           0  ...           0             0    288
# 6      44618000000           3  ...           6             6     59
# 7       3432000000           0  ...           0             0     56
# 8       1700000000           0  ...           4             0    510
# 9       1538800000           0  ...           0             0    180
# 10      3890400000           0  ...           2             0    320
# 11       723120000           0  ...           0             0    601
# 12      5513710000           0  ...           0             0      0
# 13        28908000           0  ...           0             0      0
# 14       476970000           0  ...           0             0     36
# 15      1177200000           0  ...           0             0    145
# 16      9690000000           0  ...          12             7   3022
# 17       407070000           0  ...           0             0    680
# 18       934250000           0  ...           0             0    237
# 19     11870000000           0  ...           0             0   2596
# 20     25266000000           0  ...           0             3    354
# 21     68000000000           6  ...          10             9    227
# 22    770000000000          92  ...          68           627   6612
# 23      1072600000           0  ...           0             0     79
# 24       692520000           0  ...           0             0    420
# 25      1929600000           0  ...           2             1    300
# 26      6237600000           0  ...           6             0   2044
# 27      1010070000           0  ...           0             0    200
# 28       251160000           0  ...           0             0     75
# 29       117390000           0  ...           0             0     50
#
#     Total Aircraft Strength  Total Population  Towed Artillery  Trainers  \
# 0                         0          37466414               60         0
# 1                        19           3088385                0         0
# 2                       552          43576691              450        87
# 3                       299          33642646              585        61
# 4                       218          45864941              172        70
# 5                        64           3011609              145        10
# 6                       430          25809973               54       113
# 7                       102           8884864                0        13
# 8                       149          10282283              319        32
# 9                       110           1526929               26        37
# 10                      190         164098818              371        63
# 11                      201           9441842              228        30
# 12                      115          11778842                0        43
# 13                        2            857423                0         0
# 14                       63          11758869               40        21
# 15                      151          11811335               86        29
# 16                     1057          82482383             1189       270
# 17                       82           5579889              457         0
# 18                       49          44712143               35        12
# 19                      318          43745640             2040        71
# 20                      554           9856612               76       146
# 21                      693          67081000              126       247
# 22                    13247         334998398             1339      2661
# 23                       50           3398239               64        17
# 24                      200          30842796               60         7
# 25                      256          29069153              104        80
# 26                      218         102789598              599        30
# 27                      177          30399243               43        30
# 28                       97          19077816               42        51
# 29                       90          14829988               60        38
#
#     Transports  Waterways (usable)  Power Index
# 0            0                1200       3.3736
# 1            0                  41       3.0023
# 2           58                   0       0.4724
# 3           30                1300       1.0931
# 4           22               11000       0.6091
# 5            2                   0       2.3169
# 6           38                2000       0.2377
# 7           11                   0       0.8924
# 8            2                   0       1.0251
# 9            3                   0       2.3269
# 10          13                8370       0.6851
# 11           4                2500       0.8124
# 12           8                2043       1.1451
# 13           0                   0      35.8958
# 14          14               10000       1.5708
# 15           9                   0       1.3664
# 16          81                1200       0.1961
# 17           5                1300       1.6728
# 18           2                   0       2.2436
# 19          32                2150       0.3266
# 20          39                   0       0.5859
# 21          40                3200       0.1382
# 22         982               41009       0.0453
# 23           8                1600       2.4526
# 24          18                1100       0.8272
# 25          50                7100       0.6664
# 26           9               17702       0.4521
# 27           8                   0       1.4754
# 28          11                2250       2.1966
# 29          14                   0       2.2498
#
# [30 rows x 47 columns]

# %%
#Data Exploration
final_df.describe()
# Out:
#        Active Personnel  Aircraft Carriers  Armored Vehicles  \
# count      3.000000e+01          30.000000         30.000000
# mean       1.329000e+05           0.433333       3887.166667
# std        2.622044e+05           2.028815       8544.054683
# min        0.000000e+00           0.000000         27.000000
# 25%        2.700000e+04           0.000000        533.000000
# 50%        4.850000e+04           0.000000       1005.000000
# 75%        1.242500e+05           0.000000       2413.000000
# max        1.390000e+06          11.000000      45193.000000
#
#        Attack Helicopters  Available Manpower  Coastline Coverage  Corvettes  \
# count           30.000000        3.000000e+01           30.000000  30.000000
# mean            44.833333        1.878774e+07         3034.300000   2.700000
# std            164.816948        2.995174e+07         6040.018321   5.266354
# min              0.000000        1.972070e+05            0.000000   0.000000
# 25%              0.000000        4.873038e+06            0.000000   0.000000
# 50%             10.000000        6.702882e+06          686.500000   0.000000
# 75%             22.000000        1.914499e+07         2563.000000   2.000000
# max            910.000000        1.473993e+08        25760.000000  22.000000
#
#        Dedicated Attack  Defense Budget  Destroyers  ...  Submarines  \
# count         30.000000    3.000000e+01   30.000000  ...   30.000000
# mean          36.000000    3.251085e+10    3.500000  ...    3.933333
# std          141.917898    1.400610e+11   16.771795  ...   12.511879
# min            0.000000    2.890800e+07    0.000000  ...    0.000000
# 25%            0.000000    6.475050e+08    0.000000  ...    0.000000
# 50%            0.000000    1.358000e+09    0.000000  ...    0.000000
# 75%           20.000000    6.056628e+09    0.000000  ...    2.000000
# max          783.000000    7.700000e+11   92.000000  ...   68.000000
#
#        Tanker Fleet        Tanks  Total Aircraft Strength  Total Population  \
# count     30.000000    30.000000                30.000000      3.000000e+01
# mean      22.000000   731.866667               658.433333      4.139216e+07
# std      114.291521  1372.514625              2388.826197      6.562568e+07
# min        0.000000     0.000000                 0.000000      8.574230e+05
# 25%        0.000000    63.000000                84.000000      9.545534e+06
# 50%        0.000000   262.500000               164.000000      2.244389e+07
# 75%        0.750000   487.500000               288.250000      4.370340e+07
# max      627.000000  6612.000000             13247.000000      3.349984e+08
#
#        Towed Artillery     Trainers  Transports  Waterways (usable)  \
# count        30.000000    30.000000   30.000000           30.000000
# mean        292.333333   142.300000   50.433333         3902.166667
# std         466.965208   480.160042  177.040748         8145.528018
# min           0.000000     0.000000    0.000000            0.000000
# 25%          42.250000    14.000000    4.250000            0.000000
# 50%          81.000000    34.500000   11.000000         1250.000000
# 75%         358.000000    70.750000   31.500000         2437.500000
# max        2040.000000  2661.000000  982.000000        41009.000000
#
#        Power Index
# count    30.000000
# mean      2.411790
# std       6.388041
# min       0.045300
# 25%       0.591700
# 50%       1.059100
# 75%       2.231850
# max      35.895800
#
# [8 rows x 47 columns]

# %%
sns.histplot(x = "Power Index", bins = 120, data = final_df)

# %% [markdown]
# ##Model Building

# %%
#Independent and Dependent Variables
x = final_df.iloc[:,:46]
y = final_df[["Power Index"]]

# %%
#Train Test Split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)

# %%
#Fitting to Random Forest Regressor
regressor = RandomForestRegressor(n_estimators = 200, random_state = 42)
regressor.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
#Prediction
predictions_regressor = regressor.predict(x_test)
predictions_regressor
# Out:
# array([2.313769 , 1.2440075, 3.1846495, 2.270871 , 1.446322 , 9.7065375,
#        2.5426275, 1.503941 , 1.640381 ])

# %%
#Performance Evaluation
plt.scatter(y_test, predictions_regressor)
plt.xlabel("y_test")
plt.ylabel("predictions_regressor")
# Out:
# Text(0, 0.5, 'predictions_regressor')

# %%
metrics.mean_absolute_error(y_test, predictions_regressor)
# Out:
# 1.289976777777779

# %%
metrics.r2_score(y_test, predictions_regressor)
# Out:
# -19.23477749068959

# %%
#Inferences
'''

The model is not very accurate. There is a strange outlier within our prediction that is extremely off. This is likely due to the
limited amount of training data. There are only 30 values total, and 20 are used for training. Among these is one huge outlier
value, with a power index of 35, while the rest are all under 5 (most are even less than 2). Random Forest Regression was used 
because the set of features and data did not fit the assumptions and capabilities of Linear Regression. This model could be improved
by having access to the complete dataset and by using techniques to reduce the bias. Additionally, more EDA could be conducted to
see the relationship between the independent and dependent variables. 

'''
# Out:
# '\n\nThe model is not very accurate. There is a strange outlier within our prediction that is extremely off. This is likely due to the\nlimited amount of training data. There are only 30 values total, and 20 are used for training. Among these is one huge outlier\nvalue, with a power index of 35, while the rest are all under 5 (most are even less than 2). Random Forest Regression was used \nbecause the set of features and data did not fit the assumptions and capabilities of Linear Regression. This model could be improved\nby having access to the complete dataset and by using techniques to reduce the bias. Additionally, more EDA could be conducted to\nsee the relationship between the independent and dependent variables. \n\n'
